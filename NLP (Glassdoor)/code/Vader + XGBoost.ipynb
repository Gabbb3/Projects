# %% [markdown]
# ## Import data and pre-processing

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('reviews_final_cleaned.csv')
df.head()
# Out:
#       id reviews.val.date                                     overall_review  \
# 0  44024       2020-01-01  Good benefits and flexible hours Micromanageme...
# 1  44024       2020-01-01  Good culture, advanced skillsets to learn from...
# 2  44024       2020-01-01  - Clean and bright offices \r\n- Friendly &amp...
# 3  44024       2019-09-21  there are many training program No management ...
# 4  44054       2019-09-11  no OT (work-life balance), just enough workloa...
#
#                 Location                Title  overall_rating  \
# 0  Singapore (Singapore)           Consultant             3.0
# 1  Singapore (Singapore)               Intern             5.0
# 2  Singapore (Singapore)               Intern             4.0
# 3  Singapore (Singapore)       Senior Manager             1.0
# 4  Singapore (Singapore)  IT Business Analyst             4.0
#
#    careerOpportunities_rating  compBenefits_rating  cultureValues_rating  \
# 0                         3.0                  3.0                   3.0
# 1                         4.0                  3.0                   5.0
# 2                         4.0                  4.0                   5.0
# 3                         2.0                  4.0                   1.0
# 4                         4.0                  4.0                   4.0
#
#    seniorManagement_rating  worklifeBalance_rating  \
# 0                      3.0                     4.0
# 1                      4.0                     4.0
# 2                      4.0                     5.0
# 3                      1.0                     3.0
# 4                      3.0                     5.0
#
#                   overview.industry header.employerName  \
# 0               Government Agencies             GovTech
# 1               Government Agencies             GovTech
# 2               Government Agencies             GovTech
# 3               Government Agencies             GovTech
# 4  Healthcare Product Manufacturing             Essilor
#
#                                       cleaned_review  \
# 0  ['good', 'benefit', 'flexible', 'hour', 'micro...
# 1  ['good', 'culture', 'advanced', 'skillsets', '...
# 2  ['clean', 'bright', 'office', 'friendly', 'amp...
# 3  ['many', 'training', 'program', 'management', ...
# 4  ['ot', 'work', 'life', 'balance', 'enough', 'w...
#
#                                      cleaned_review2
# 0  ['good', 'benefit', 'flexibl', 'hour', 'microm...
# 1  ['good', 'cultur', 'advanc', 'skillset', 'lear...
# 2  ['clean', 'bright', 'offic', 'friend', 'amp', ...
# 3  ['mani', 'train', 'program', 'manag', 'skill',...
# 4  ['ot', 'work', 'life', 'balanc', 'enough', 'wo...

# %%
#Review class proportion
print(df['overall_review'].count(),'\n\n',df['overall_rating'].value_counts(),'\n\n',
      df['overall_review'].count()==df['overall_rating'].count())
# Out:
# 11742
#
#  5.0    4373
# 4.0    3691
# 3.0    1668
# 1.0    1272
# 2.0     738
# Name: overall_rating, dtype: int64
#
#  True

# %%
#Remove NaN and blank 'review text' strings
df.dropna(inplace=True)

blanks=[]

for i in df.index:
    if type(df.iloc[i,2])==str:
        if df.iloc[i,2].isspace():
            blanks.append(i)

df.drop(blanks, inplace=True)

# %%
#Check if any NaN and blank strings were removed
print(df['overall_review'].count(),'\n\n',df['overall_rating'].value_counts(),'\n\n',
      df['overall_review'].count()==df['overall_rating'].count())
# Out:
# 11742
#
#  5.0    4373
# 4.0    3691
# 3.0    1668
# 1.0    1272
# 2.0     738
# Name: overall_rating, dtype: int64
#
#  True

# %% [markdown]
# ## Import NLTK and VADER

# %%
import nltk
#Download "Vader" - Optional
#nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

# %% [markdown]
# ## Apply VADER

# %%
#Apply VADER to 'overall_review' text column
df['scores'] = df['overall_review'].apply(lambda review: sid.polarity_scores(review))

# %%
df.head().scores
# Out:
# 0    {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'comp...
# 1    {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'comp...
# 2    {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...
# 3    {'neg': 0.197, 'neu': 0.673, 'pos': 0.13, 'com...
# 4    {'neg': 0.1, 'neu': 0.773, 'pos': 0.127, 'comp...
# Name: scores, dtype: object

# %%
#Split the VADER sentiments scores into columns in the df
df['positive'] = df['scores'].apply(lambda score_dict: score_dict['pos'])
df['negative'] = df['scores'].apply(lambda score_dict: score_dict['neg'])
df['neutral'] = df['scores'].apply(lambda score_dict: score_dict['neu'])
df['compound']  =df['scores'].apply(lambda score_dict: score_dict['compound'])

# %%
df.head()
# Out:
#       id reviews.val.date                                     overall_review  \
# 0  44024       2020-01-01  Good benefits and flexible hours Micromanageme...
# 1  44024       2020-01-01  Good culture, advanced skillsets to learn from...
# 2  44024       2020-01-01  - Clean and bright offices \r\n- Friendly &amp...
# 3  44024       2019-09-21  there are many training program No management ...
# 4  44054       2019-09-11  no OT (work-life balance), just enough workloa...
#
#                 Location                Title  overall_rating  \
# 0  Singapore (Singapore)           Consultant             3.0
# 1  Singapore (Singapore)               Intern             5.0
# 2  Singapore (Singapore)               Intern             4.0
# 3  Singapore (Singapore)       Senior Manager             1.0
# 4  Singapore (Singapore)  IT Business Analyst             4.0
#
#    careerOpportunities_rating  compBenefits_rating  cultureValues_rating  \
# 0                         3.0                  3.0                   3.0
# 1                         4.0                  3.0                   5.0
# 2                         4.0                  4.0                   5.0
# 3                         2.0                  4.0                   1.0
# 4                         4.0                  4.0                   4.0
#
#    seniorManagement_rating  worklifeBalance_rating  \
# 0                      3.0                     4.0
# 1                      4.0                     4.0
# 2                      4.0                     5.0
# 3                      1.0                     3.0
# 4                      3.0                     5.0
#
#                   overview.industry header.employerName  \
# 0               Government Agencies             GovTech
# 1               Government Agencies             GovTech
# 2               Government Agencies             GovTech
# 3               Government Agencies             GovTech
# 4  Healthcare Product Manufacturing             Essilor
#
#                                       cleaned_review  \
# 0  ['good', 'benefit', 'flexible', 'hour', 'micro...
# 1  ['good', 'culture', 'advanced', 'skillsets', '...
# 2  ['clean', 'bright', 'office', 'friendly', 'amp...
# 3  ['many', 'training', 'program', 'management', ...
# 4  ['ot', 'work', 'life', 'balance', 'enough', 'w...
#
#                                      cleaned_review2  \
# 0  ['good', 'benefit', 'flexibl', 'hour', 'microm...
# 1  ['good', 'cultur', 'advanc', 'skillset', 'lear...
# 2  ['clean', 'bright', 'offic', 'friend', 'amp', ...
# 3  ['mani', 'train', 'program', 'manag', 'skill',...
# 4  ['ot', 'work', 'life', 'balanc', 'enough', 'wo...
#
#                                               scores  positive  negative  \
# 0  {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'comp...     0.481     0.000
# 1  {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'comp...     0.214     0.000
# 2  {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...     0.423     0.000
# 3  {'neg': 0.197, 'neu': 0.673, 'pos': 0.13, 'com...     0.130     0.197
# 4  {'neg': 0.1, 'neu': 0.773, 'pos': 0.127, 'comp...     0.127     0.100
#
#    neutral  compound
# 0    0.519    0.7506
# 1    0.786    0.5994
# 2    0.577    0.8316
# 3    0.673   -0.1280
# 4    0.773    0.1531

# %%
#Check y-label data type
df['overall_rating'].dtype
# Out:
# dtype('float64')

# %%
# Create Feature (VADER scores - Predictor) and Label (Rating - Prediction) sets for rating classifier using ML
X = df[['positive','negative','neutral','compound']]
y = df['overall_rating']

# %% [markdown]
# ## XGBoost Classifier (Search for params with CV)

# %% [markdown]
# We perform a rating classification with the VADER scores using a classifer: XGBoost. We first obtain the optimal parameters for the XGBoost classifier through hyperparameter search function and then apply those for final prediction.

# %%
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix, classification_report, matthews_corrcoef

# %% [markdown]
# We base the optimal parameter search using scoring: MCC (Matthews correlation coefficient). The coefficient takes into account true and false positives and negatives and is generally regarded as a balanced measure which can be used even if the classes are of very different sizes. It can be argued that predicting rating (1) vs (3) vs (5) wrongly may be equally costly, hence the balance approach may be appropriate.

# %%
xgb_model_cv = xgb.XGBClassifier(objective = 'multi:softprob')

params = {'n_estimators': [1000],
              'learning_rate': stats.uniform(0.01, 0.07),
              'subsample': stats.uniform(0.3, 0.7),
              'max_depth': [3, 4, 5, 6, 7, 8, 9],
              'colsample_bytree': stats.uniform(0.5, 0.45),
              'min_child_weight': [1, 2, 3]
             }

MCC_scoring = make_scorer(matthews_corrcoef)
search = RandomizedSearchCV(xgb_model_cv, param_distributions=params, scoring=MCC_scoring,
                            random_state=0, n_iter=25, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed: 49.3min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            learning_rate=0.1, max_delta_step=0,
#                                            max_depth=3, min_child_weight=1,
#                                            missing=None, n_estimators=100,
#                                            n_jobs=1, nthread=None,
#                                            objective='multi:softprob',
#                                            random_state=0, reg_alpha=0,
#                                            reg_lambda=1, sca...
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002C453F98788>,
#                                         'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                                         'min_child_weight': [1, 2, 3],
#                                         'n_estimators': [1000],
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002C453F98D08>},
#                    pre_dispatch='2*n_jobs', random_state=0, refit=True,
#                    return_train_score=True,
#                    scoring=make_scorer(matthews_corrcoef), verbose=1)

# %%
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %% [markdown]
# Best model iteration achieve a 5-fold CV score of mean 0.915 with standard deviation of 0.009.

# %%
#Obtain the best 5-fold cv model results
report_best_scores(search.cv_results_, 1)
# Out:
# Model with rank: 1
# Mean validation score: 0.915 (std: 0.009)
# Parameters: {'colsample_bytree': 0.8892961525874232, 'learning_rate': 0.04562782724669102, 'max_depth': 9, 'min_child_weight': 2, 'n_estimators': 1000, 'subsample': 0.9448103271660397}

# %%
#All hyperparameter search results
search.cv_results_
# Out:
# {'mean_fit_time': array([18.5461432 , 12.50150852, 27.07565579, 22.06939516, 16.76081247,
#         12.15599484, 22.65410304, 11.37326388, 26.19000049, 15.07591791,
#         24.48313818, 17.40272365, 25.49526124, 15.59579253, 18.03301096,
#         17.48630133, 12.35990276, 15.49015164, 21.70415258, 25.29574175,
#         11.96460919, 21.43225455, 24.15384965, 25.23164802, 20.4558188 ]),
#  'std_fit_time': array([0.1772133 , 0.18150479, 0.09090052, 0.27783403, 0.16009472,
#         0.1093701 , 0.21670458, 0.20740178, 0.11631261, 0.25245598,
#         0.4368029 , 0.31646421, 0.26886075, 0.23364289, 0.20251664,
#         0.26423259, 0.20295659, 0.05990511, 0.16506018, 0.13333402,
#         0.2180399 , 0.20723501, 0.16057322, 0.36456187, 0.29832673]),
#  'mean_score_time': array([0.83153381, 0.38442273, 1.58826389, 1.04600105, 0.63585463,
#         0.37437644, 0.93984699, 0.34843755, 1.21667042, 0.45500469,
#         0.98071642, 1.09135356, 1.3082612 , 0.62728653, 1.0156394 ,
#         1.0960259 , 0.3958025 , 0.69724545, 0.84159889, 1.63897715,
#         0.36230078, 0.80871024, 2.06466727, 1.56704731, 0.67519822]),
#  'std_score_time': array([0.04629263, 0.05372528, 0.02123615, 0.02481202, 0.0515243 ,
#         0.01415397, 0.0129424 , 0.0034267 , 0.19887606, 0.00764313,
#         0.12046992, 0.07618462, 0.15860575, 0.02111572, 0.28268377,
#         0.03937637, 0.03718723, 0.07423251, 0.10091522, 0.27117371,
#         0.00273528, 0.11198709, 0.31044878, 0.19375925, 0.01721069]),
#  'param_colsample_bytree': masked_array(data=[0.7469660767672961, 0.6729717682817149,
#                     0.7149493027946074, 0.8762354435918198,
#                     0.8501705379274327, 0.7342148657980422,
#                     0.9251010126723127, 0.7052676494974468,
#                     0.7754430752250896, 0.7758785560478596,
#                     0.8017870413281718, 0.6636698469241802,
#                     0.7937556426524709, 0.686465864701866,
#                     0.6427407839311833, 0.5061072360254494,
#                     0.8951870621062297, 0.5176345065144443,
#                     0.896214150163668, 0.8892961525874232,
#                     0.5374006216837711, 0.8223472418533545,
#                     0.5090483957843721, 0.6215035879364742,
#                     0.7592708004880266],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.06006325564606937, 0.03082742245811306,
#                     0.06685181101428453, 0.03361773122920879,
#                     0.07090085037727735, 0.057521567108327225,
#                     0.04652938252250502, 0.0497903764208054,
#                     0.05318537978123299, 0.0731644008221789,
#                     0.024726779275168864, 0.04991377392925158,
#                     0.05445412115224947, 0.04322882516018891,
#                     0.06448418374181364, 0.05359922668826687,
#                     0.045673706370393016, 0.029796487380348673,
#                     0.07427648264535013, 0.04562782724669102,
#                     0.029440299289672275, 0.03025842650630408,
#                     0.06802580204521542, 0.06146358154858165,
#                     0.05144293518902874],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[6, 3, 9, 7, 5, 3, 7, 3, 7, 4, 6, 7, 7, 5, 6, 7, 3, 5,
#                     6, 9, 3, 6, 9, 8, 5],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_weight': masked_array(data=[2, 1, 1, 1, 1, 2, 3, 1, 2, 2, 1, 1, 1, 2, 1, 3, 2, 3,
#                     3, 2, 3, 3, 1, 1, 1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000,
#                     1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000,
#                     1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_subsample': masked_array(data=[0.7364945877501806, 0.4908594062060792,
#                     0.5749493572705808, 0.8828338918835565,
#                     0.8606375263857509, 0.40034730118633244,
#                     0.8419635826039515, 0.7323448479531138,
#                     0.6149649929378593, 0.7667367008119673,
#                     0.5207998456469287, 0.9712644880371641,
#                     0.707295230606974, 0.7723266255813144,
#                     0.763768806865031, 0.980361501749766,
#                     0.8174845055788111, 0.7820628279640391,
#                     0.6956322066234126, 0.9448103271660397,
#                     0.3922585036830745, 0.7105590543670581,
#                     0.774471575757361, 0.4741272004639706,
#                     0.4561571428484328],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'colsample_bytree': 0.7469660767672961,
#    'learning_rate': 0.06006325564606937,
#    'max_depth': 6,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.7364945877501806},
#   {'colsample_bytree': 0.6729717682817149,
#    'learning_rate': 0.03082742245811306,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.4908594062060792},
#   {'colsample_bytree': 0.7149493027946074,
#    'learning_rate': 0.06685181101428453,
#    'max_depth': 9,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.5749493572705808},
#   {'colsample_bytree': 0.8762354435918198,
#    'learning_rate': 0.03361773122920879,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.8828338918835565},
#   {'colsample_bytree': 0.8501705379274327,
#    'learning_rate': 0.07090085037727735,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.8606375263857509},
#   {'colsample_bytree': 0.7342148657980422,
#    'learning_rate': 0.057521567108327225,
#    'max_depth': 3,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.40034730118633244},
#   {'colsample_bytree': 0.9251010126723127,
#    'learning_rate': 0.04652938252250502,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.8419635826039515},
#   {'colsample_bytree': 0.7052676494974468,
#    'learning_rate': 0.0497903764208054,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.7323448479531138},
#   {'colsample_bytree': 0.7754430752250896,
#    'learning_rate': 0.05318537978123299,
#    'max_depth': 7,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.6149649929378593},
#   {'colsample_bytree': 0.7758785560478596,
#    'learning_rate': 0.0731644008221789,
#    'max_depth': 4,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.7667367008119673},
#   {'colsample_bytree': 0.8017870413281718,
#    'learning_rate': 0.024726779275168864,
#    'max_depth': 6,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.5207998456469287},
#   {'colsample_bytree': 0.6636698469241802,
#    'learning_rate': 0.04991377392925158,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.9712644880371641},
#   {'colsample_bytree': 0.7937556426524709,
#    'learning_rate': 0.05445412115224947,
#    'max_depth': 7,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.707295230606974},
#   {'colsample_bytree': 0.686465864701866,
#    'learning_rate': 0.04322882516018891,
#    'max_depth': 5,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.7723266255813144},
#   {'colsample_bytree': 0.6427407839311833,
#    'learning_rate': 0.06448418374181364,
#    'max_depth': 6,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.763768806865031},
#   {'colsample_bytree': 0.5061072360254494,
#    'learning_rate': 0.05359922668826687,
#    'max_depth': 7,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.980361501749766},
#   {'colsample_bytree': 0.8951870621062297,
#    'learning_rate': 0.045673706370393016,
#    'max_depth': 3,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.8174845055788111},
#   {'colsample_bytree': 0.5176345065144443,
#    'learning_rate': 0.029796487380348673,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.7820628279640391},
#   {'colsample_bytree': 0.896214150163668,
#    'learning_rate': 0.07427648264535013,
#    'max_depth': 6,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.6956322066234126},
#   {'colsample_bytree': 0.8892961525874232,
#    'learning_rate': 0.04562782724669102,
#    'max_depth': 9,
#    'min_child_weight': 2,
#    'n_estimators': 1000,
#    'subsample': 0.9448103271660397},
#   {'colsample_bytree': 0.5374006216837711,
#    'learning_rate': 0.029440299289672275,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.3922585036830745},
#   {'colsample_bytree': 0.8223472418533545,
#    'learning_rate': 0.03025842650630408,
#    'max_depth': 6,
#    'min_child_weight': 3,
#    'n_estimators': 1000,
#    'subsample': 0.7105590543670581},
#   {'colsample_bytree': 0.5090483957843721,
#    'learning_rate': 0.06802580204521542,
#    'max_depth': 9,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.774471575757361},
#   {'colsample_bytree': 0.6215035879364742,
#    'learning_rate': 0.06146358154858165,
#    'max_depth': 8,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.4741272004639706},
#   {'colsample_bytree': 0.7592708004880266,
#    'learning_rate': 0.05144293518902874,
#    'max_depth': 5,
#    'min_child_weight': 1,
#    'n_estimators': 1000,
#    'subsample': 0.4561571428484328}],
#  'split0_test_score': array([0.89954456, 0.74029991, 0.90956107, 0.90837404, 0.90488753,
#         0.78626346, 0.90372198, 0.79642522, 0.90837774, 0.87964476,
#         0.87446568, 0.90663967, 0.91020713, 0.86980777, 0.90720136,
#         0.90016225, 0.79209185, 0.84605122, 0.90608207, 0.91136255,
#         0.71893768, 0.87437558, 0.90902556, 0.90955428, 0.88955011]),
#  'split1_test_score': array([0.9102138 , 0.74179264, 0.91727984, 0.91725821, 0.91724247,
#         0.79349316, 0.91487928, 0.79670248, 0.9161109 , 0.89077277,
#         0.8884283 , 0.91676062, 0.91964475, 0.88672794, 0.91373685,
#         0.91199097, 0.79478804, 0.85012294, 0.91435907, 0.9202158 ,
#         0.72618397, 0.88848076, 0.91732065, 0.91841711, 0.89958883]),
#  'split2_test_score': array([0.91084113, 0.72661567, 0.91960511, 0.91253726, 0.91083607,
#         0.79165131, 0.91137562, 0.7982072 , 0.91667404, 0.88065407,
#         0.88364426, 0.91562673, 0.91669975, 0.87369452, 0.91727242,
#         0.91019524, 0.79159595, 0.84759006, 0.91434692, 0.91902285,
#         0.71648104, 0.88418491, 0.91844308, 0.91846532, 0.89715882]),
#  'split3_test_score': array([0.91570867, 0.76053754, 0.93252249, 0.92046766, 0.91992163,
#         0.808377  , 0.92656959, 0.80453055, 0.93249455, 0.89684392,
#         0.90069818, 0.92154052, 0.93309207, 0.89305024, 0.9307546 ,
#         0.92098838, 0.81691811, 0.86890044, 0.92513949, 0.9269455 ,
#         0.74280018, 0.89949216, 0.92634812, 0.93017647, 0.91302216]),
#  'split4_test_score': array([0.89382479, 0.73372853, 0.89307825, 0.8967099 , 0.89568877,
#         0.77208483, 0.89730447, 0.77307086, 0.89429649, 0.87353566,
#         0.8720203 , 0.89909397, 0.89485356, 0.86841599, 0.89546127,
#         0.89371448, 0.77693445, 0.83124443, 0.89433368, 0.89915778,
#         0.70915995, 0.86778817, 0.89431603, 0.8937108 , 0.88436924]),
#  'mean_test_score': array([0.90602659, 0.74059486, 0.91440935, 0.91106941, 0.9097153 ,
#         0.79037395, 0.91077019, 0.79378726, 0.91359075, 0.88429024,
#         0.88385134, 0.9119323 , 0.91489945, 0.87833929, 0.9128853 ,
#         0.90741026, 0.79446568, 0.84878182, 0.91085225, 0.91534089,
#         0.72271257, 0.88286431, 0.91309069, 0.9140648 , 0.89673783]),
#  'std_test_score': array([0.00806667, 0.01132958, 0.01297569, 0.00827337, 0.00874225,
#         0.01172057, 0.00997873, 0.01076644, 0.01243105, 0.00836757,
#         0.01032348, 0.00802638, 0.01249469, 0.00979402, 0.01162057,
#         0.00952063, 0.01284858, 0.01202492, 0.01023966, 0.00948376,
#         0.01142206, 0.01103741, 0.01087486, 0.01210391, 0.00977886]),
#  'rank_test_score': array([14, 24,  3,  9, 12, 23, 11, 22,  5, 16, 17,  8,  2, 19,  7, 13, 21,
#         20, 10,  1, 25, 18,  6,  4, 15]),
#  'split0_train_score': array([0.96655377, 0.78637289, 0.97255599, 0.96833978, 0.96804662,
#         0.85376037, 0.96832951, 0.85408436, 0.97137639, 0.94589728,
#         0.94194655, 0.97019755, 0.97257933, 0.93859959, 0.97020324,
#         0.96611142, 0.84555403, 0.90960632, 0.97053423, 0.97243137,
#         0.76972791, 0.94266148, 0.97257933, 0.97240612, 0.95629526]),
#  'split1_train_score': array([0.96176518, 0.78507699, 0.97012835, 0.96554944, 0.96439731,
#         0.8464665 , 0.96527655, 0.84358775, 0.96864805, 0.9441208 ,
#         0.93954691, 0.96762109, 0.96998029, 0.93473971, 0.96701845,
#         0.96189449, 0.84131048, 0.90393143, 0.96748658, 0.96954085,
#         0.7668609 , 0.93941963, 0.97012835, 0.96997305, 0.95163813]),
#  'split2_train_score': array([0.96267179, 0.77842369, 0.97069239, 0.96411829, 0.9642674 ,
#         0.84316149, 0.96483741, 0.85050321, 0.96908241, 0.93986419,
#         0.9362149 , 0.96719148, 0.97070551, 0.92940066, 0.96762831,
#         0.96223365, 0.83777283, 0.90366631, 0.96747183, 0.96997759,
#         0.75980272, 0.9359026 , 0.97070231, 0.97069661, 0.9517583 ]),
#  'split3_train_score': array([0.95988084, 0.78130106, 0.96878211, 0.96314803, 0.96211721,
#         0.84474577, 0.9621746 , 0.84760216, 0.9664315 , 0.93970411,
#         0.93685519, 0.9649136 , 0.96863464, 0.93131803, 0.9648128 ,
#         0.95974777, 0.84166917, 0.90357485, 0.96565504, 0.9677058 ,
#         0.75698694, 0.93623087, 0.96888073, 0.968636  , 0.95015965]),
#  'split4_train_score': array([0.96596146, 0.79482138, 0.97255984, 0.96802627, 0.96832239,
#         0.84616129, 0.96816929, 0.84684135, 0.97139602, 0.94713067,
#         0.94294501, 0.96963629, 0.97241482, 0.93574628, 0.97035456,
#         0.96538069, 0.85297572, 0.90199136, 0.97021476, 0.97197278,
#         0.77578206, 0.94246944, 0.97255984, 0.97241661, 0.95626171]),
#  'mean_train_score': array([0.96336661, 0.7851992 , 0.97094374, 0.96583636, 0.96543018,
#         0.84685909, 0.96575747, 0.84852376, 0.96938688, 0.94334341,
#         0.93950172, 0.967912  , 0.97086292, 0.93396085, 0.96800347,
#         0.9630736 , 0.84385645, 0.90455405, 0.96827249, 0.97032568,
#         0.76583211, 0.9393368 , 0.97097011, 0.97082568, 0.95322261]),
#  'std_train_score': array([0.00253334, 0.00556924, 0.00145683, 0.00206514, 0.00239187,
#         0.00364437, 0.00229552, 0.00354634, 0.00186374, 0.00306005,
#         0.00266994, 0.00188632, 0.00149155, 0.00325859, 0.00208125,
#         0.00235406, 0.00518304, 0.00261639, 0.00184378, 0.00171743,
#         0.00677979, 0.0029091 , 0.00143266, 0.00145377, 0.00255788])}

# %% [markdown]
# ## XGBoost Classifier (Predict with optimised param)

# %% [markdown]
# We predict using the above optimised parameters.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

print('Training Data Shape:', X_train.shape)
print('Testing Data Shape: ', X_test.shape)
# Out:
# Training Data Shape: (10567, 4)
# Testing Data Shape:  (1175, 4)

# %%
xgb_model = xgb.XGBClassifier(silent=False, 
                              scale_pos_weight=1,
                              learning_rate=0.04562782724669102,  
                              colsample_bytree = 0.8892961525874232,
                              subsample = 0.9448103271660397,
                              objective='multi:softprob', 
                              n_estimators=1000, 
                              reg_alpha = 0.3,
                              min_child_weight = 2,
                              max_depth=9, 
                              gamma=1)

# %%
xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8892961525874232, gamma=1,
#               learning_rate=0.04562782724669102, max_delta_step=0, max_depth=9,
#               min_child_weight=2, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0.3, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=False, subsample=0.9448103271660397, verbosity=1)

# %%
y_pred = xgb_model.predict(X_test)

# %% [markdown]
# Achieved an MCC-score of 0.918.

# %%
#Print scores
print(confusion_matrix(y_test, y_pred),'\n')
print(classification_report(y_test,y_pred),'\n')
print('MCC-score:', matthews_corrcoef(y_test,y_pred))
# Out:
# [[112   0   2   1   3]
#  [  2  67   2   2   2]
#  [  1   1 134  13  11]
#  [  0   3   4 361  12]
#  [  0   0   3   7 432]]
#
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.95      0.96       118
#          2.0       0.94      0.89      0.92        75
#          3.0       0.92      0.84      0.88       160
#          4.0       0.94      0.95      0.95       380
#          5.0       0.94      0.98      0.96       442
#
#     accuracy                           0.94      1175
#    macro avg       0.94      0.92      0.93      1175
# weighted avg       0.94      0.94      0.94      1175
#
#
# MCC-score: 0.918342304757046
